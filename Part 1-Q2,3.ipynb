# %% [markdown]
# Q2. Which field of study leads to the highest debt after graduation?

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
college_df = pd.read_csv(r'/content/drive/My Drive/DATA 606/Final.csv')

# %%
college_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  ...  relative_value_dollar_2017  national_rank
# 0           0            62  ...                      115.34           71.0
# 1           1            64  ...                      115.34           71.0
# 2           2            69  ...                      115.34           71.0
# 3           3            72  ...                      115.34           71.0
# 4           4            73  ...                      115.34           71.0
#
# [5 rows x 30 columns]

# %%
del college_df['Unnamed: 0.1']
del college_df['Unnamed: 0']

# %%
#Sorting the data w.r.t to the debt values

top_debt=college_df[['DEBTMEDIAN','CIPDESC','CREDDESC','INSTNM']].sort_values(by='DEBTMEDIAN',ascending=False).head(50)
top_debt
# Out:
#       DEBTMEDIAN  ...                                       INSTNM
# 479       403691  ...            University of Southern California
# 4119      387660  ...                          New York University
# 4504      339019  ...              Case Western Reserve University
# 1001      316711  ...                             Tufts University
# 299       308863  ...                        Loma Linda University
# 1178      299503  ...                            Howard University
# 3849      286484  ...                            Temple University
# 4588      276675  ...           Oregon Health & Science University
# 870       267680  ...                            Boston University
# 480       266826  ...            University of Southern California
# 3973      265000  ...                         Creighton University
# 4275      263704  ...                       Stony Brook University
# 3718      263037  ...                            Drexel University
# 2841      248418  ...                     University of Louisville
# 1907      248114  ...            University of Illinois at Chicago
# 3004      244739  ...                    Michigan State University
# 1527      237972  ...                        University of Florida
# 4058      237893  ...                     New York Medical College
# 3002      235162  ...                    Michigan State University
# 1151      233128  ...                        Georgetown University
# 3975      225511  ...                         Creighton University
# 2330      224958  ...                         Marquette University
# 3629      221469  ...             Virginia Commonwealth University
# 4590      221089  ...           Oregon Health & Science University
# 1956      218264  ...                    Loyola University Chicago
# 3997      218235  ...                       Albany Medical College
# 1180      218113  ...                            Howard University
# 913       216775  ...                           Harvard University
# 1002      216620  ...                             Tufts University
# 2789      213573  ...                       University of Kentucky
# 2448      212964  ...                           University of Iowa
# 3850      209636  ...                            Temple University
# 2793      206804  ...                       University of Kentucky
# 1004      205928  ...                             Tufts University
# 1349      205884  ...             Florida International University
# 1111      205433  ...                 George Washington University
# 4575      204941  ...                         University of Toledo
# 3853      204367  ...                            Temple University
# 872       203570  ...                            Boston University
# 487       203282  ...            University of Southern California
# 312       202421  ...                        Loma Linda University
# 310       201550  ...                        Loma Linda University
# 2844      199698  ...                     University of Louisville
# 300       199097  ...                        Loma Linda University
# 301       198965  ...                        Loma Linda University
# 2703      196897  ...                       Wake Forest University
# 484       196428  ...            University of Southern California
# 524       195646  ...  University of Arkansas for Medical Sciences
# 3634      194390  ...             Virginia Commonwealth University
# 4279      194062  ...                       Stony Brook University
#
# [50 rows x 4 columns]

# %%
top_debt['CIPDESC'].value_counts().plot(kind="bar")

# %%
college_df.groupby('CIPDESC')['DEBTMEDIAN'].nunique().nlargest(5)
# Out:
# CIPDESC
# Business Administration, Management and Operations                                   136
# Registered Nursing, Nursing Administration, Nursing Research and Clinical Nursing    125
# Accounting and Related Services                                                       93
# Biology, General                                                                      81
# Mechanical Engineering                                                                78
# Name: DEBTMEDIAN, dtype: int64

# %% [markdown]
# Takeaway points:<br>
# 1. Study fields 'Dentistry', 'Osteopathy' and 'Medicine' top the list of students left with highest amount of debt after graduation.<br>
# 2. Study fields 'Business Administration', 'Registered Nursing and Nursing Research' and 'Liberal Arts and Sciences' have left highest number of students with debt.

# %% [markdown]
# Q3. Bachelor's vs Master's vs Doctoral degree: which degree leads to high earning and less debt?

# %%
college_df['CIPDESC'].nunique()
# Out:
# 246

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
degrees = ["Bachelor's Degree","Master's Degree","Doctoral Degree"]
college_df_req = college_df[college_df.CREDDESC.isin(degrees)]

# %%
plt.figure(figsize=(20, 7))
plt.title("Median earnings after graduation")  
sns.boxplot(y='CREDDESC', x='MD_EARN_WNE', 
                 data=college_df_req,
                 palette="colorblind",
                hue='CREDDESC')

# %%
plt.figure(figsize=(20, 7))
plt.title("Median debt of students after graduation")
sns.boxplot(y='CREDDESC', x='DEBTMEDIAN', 
                 data=college_df_req,
                 palette="colorblind",
                hue='CREDDESC')

# %% [markdown]
# After comparing the box plots, we can conclude there is no degree which leaves a student with high earning and less debt. Students having a higher degree seem to have both high pay and high debt and vice versa.
